# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Import data
df = pd.read_csv("/Users/Mandeep/Downloads/Comcast_telecom_complaints_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ticket #                     2224 non-null   object
#  1   Customer Complaint           2224 non-null   object
#  2   Date                         2224 non-null   object
#  3   Date_month_year              2224 non-null   object
#  4   Time                         2224 non-null   object
#  5   Received Via                 2224 non-null   object
#  6   City                         2224 non-null   object
#  7   State                        2224 non-null   object
#  8   Zip code                     2224 non-null   int64
#  9   Status                       2224 non-null   object
#  10  Filing on Behalf of Someone  2224 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 191.2+ KB

# %%
df.head()
# Out:
#   Ticket #                                 Customer Complaint      Date  \
# 0   250635                      Comcast Cable Internet Speeds  22-04-15
# 1   223441       Payment disappear - service got disconnected  04-08-15
# 2   242732                                  Speed and Service  18-04-15
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4   307175         Comcast not working and no service to boot  26-05-15
#
#   Date_month_year         Time        Received Via      City     State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1       04-Aug-15  10:22:56 AM            Internet   Acworth   Georgia
# 2       18-Apr-15   9:55:47 AM            Internet   Acworth   Georgia
# 3       05-Jul-15  11:59:35 AM            Internet   Acworth   Georgia
# 4       26-May-15   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone
# 0     21009  Closed                          No
# ...

# %%
df.tail()
# Out:
#      Ticket #                          Customer Complaint      Date  \
# 2219   213550                        Service Availability  04-02-15
# 2220   318775  Comcast Monthly Billing for Returned Modem  06-02-15
# 2221   331188                     complaint about comcast  06-09-15
# 2222   360489      Extremely unsatisfied Comcast customer  23-06-15
# 2223   363614        Comcast, Ypsilanti MI Internet Speed  24-06-15
#
#      Date_month_year         Time        Received Via        City     State  \
# 2219       04-Feb-15   9:13:18 AM  Customer Care Call  Youngstown   Florida
# 2220       06-Feb-15   1:24:39 PM  Customer Care Call   Ypsilanti  Michigan
# 2221       06-Sep-15   5:28:41 PM            Internet   Ypsilanti  Michigan
# 2222       23-Jun-15  11:13:30 PM  Customer Care Call   Ypsilanti  Michigan
# 2223       24-Jun-15  10:28:33 PM  Customer Care Call   Ypsilanti  Michigan
#
#       Zip code  Status Filing on Behalf of Someone
# ...

# %%
#step 1: to check for null values
df.isnull().sum()
# Out:
# Ticket #                       0
# Customer Complaint             0
# Date                           0
# Date_month_year                0
# Time                           0
# Received Via                   0
# City                           0
# State                          0
# Zip code                       0
# Status                         0
# Filing on Behalf of Someone    0
# dtype: int64

# %%
df.drop(['Ticket #','Time'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer Complaint           2224 non-null   object
#  1   Date                         2224 non-null   object
#  2   Date_month_year              2224 non-null   object
#  3   Received Via                 2224 non-null   object
#  4   City                         2224 non-null   object
#  5   State                        2224 non-null   object
#  6   Zip code                     2224 non-null   int64
#  7   Status                       2224 non-null   object
#  8   Filing on Behalf of Someone  2224 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 156.5+ KB

# %%
df['Date_month_year']= df['Date_month_year'].apply(pd.to_datetime)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer Complaint           2224 non-null   object
#  1   Date                         2224 non-null   object
#  2   Date_month_year              2224 non-null   datetime64[ns]
#  3   Received Via                 2224 non-null   object
#  4   City                         2224 non-null   object
#  5   State                        2224 non-null   object
#  6   Zip code                     2224 non-null   int64
#  7   Status                       2224 non-null   object
#  8   Filing on Behalf of Someone  2224 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 156.5+ KB

# %%
df = df.set_index('Date_month_year')

# %%
df.head()
# Out:
#                                                 Customer Complaint      Date  \
# Date_month_year
# 2015-04-22                           Comcast Cable Internet Speeds  22-04-15
# 2015-08-04            Payment disappear - service got disconnected  04-08-15
# 2015-04-18                                       Speed and Service  18-04-15
# 2015-07-05       Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 2015-05-26              Comcast not working and no service to boot  26-05-15
#
#                        Received Via      City     State  Zip code  Status  \
# Date_month_year
# 2015-04-22       Customer Care Call  Abingdon  Maryland     21009  Closed
# 2015-08-04                 Internet   Acworth   Georgia     30102  Closed
# 2015-04-18                 Internet   Acworth   Georgia     30101  Closed
# 2015-07-05                 Internet   Acworth   Georgia     30101    Open
# 2015-05-26                 Internet   Acworth   Georgia     30101  Solved
#
# ...

# %%
#Provide the trend chart for the number of monthly complaints
month = df.groupby(pd.Grouper(freq='m')).size().plot()
plt.xlabel('Months')
plt.ylabel('complain frequency')
plt.title('Monthly Trend Chart')
# Out:
# Text(0.5, 1.0, 'Monthly Trend Chart')

# %%
df['Date'].value_counts()
# Out:
# 24-06-15    218
# 23-06-15    190
# 25-06-15     98
# 26-06-15     55
# 30-06-15     53
#            ...
# 24-05-15      7
# 05-10-15      7
# 04-05-15      6
# 05-03-15      5
# 04-11-15      5
# Name: Date, Length: 91, dtype: int64

# %%
df = df.sort_values('Date')

# %%
df.head(10)
# Out:
#                                                 Customer Complaint      Date  \
# Date_month_year
# 2015-01-04        Fraudulent claims reported to collections agency  04-01-15
# 2015-01-04                              Comcast refusal of service  04-01-15
# 2015-01-04                                           Comcast Cable  04-01-15
# 2015-01-04                                           Data Overages  04-01-15
# 2015-01-04                                                 Comcast  04-01-15
# 2015-01-04                                      Comcast harassment  04-01-15
# 2015-01-04       Comcast is ignoring me now. They are making NO...  04-01-15
# 2015-01-04       Unable to get in touch with anyone that has th...  04-01-15
# 2015-01-04             Comcast Lied About Pricing And Installation  04-01-15
# 2015-01-04                                             overcharged  04-01-15
#
#                        Received Via              City         State  Zip code  \
# Date_month_year
# ...

# %%
#Provide the trend chart for the number of daily complaints
df['Date'].value_counts().plot()
plt.xlabel('Date')
plt.ylabel('complaint Frequency')
plt.title('Daily Trend Chart')
# Out:
# Text(0.5, 1.0, 'Daily Trend Chart')

# %%
#Provide a table with the frequency of complaint types.
df['Customer Complaint'].value_counts()
# Out:
# Comcast                                                       83
# Comcast Internet                                              18
# Comcast Data Cap                                              17
# comcast                                                       13
# Comcast Data Caps                                             11
#                                                               ..
# Comcast fraud                                                  1
# Ongoing serious and cotinued internet service outages          1
# Complaint #2. No resolution. Please help. Thank you.           1
# Comcast / Xfinity overcharging for internet / internet cap     1
# Horrible Customer Service, Bad Service                         1
# Name: Customer Complaint, Length: 1841, dtype: int64

# %%
df['Customer Complaint'].value_counts()[:10].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['Customer Complaint'][10:]
# Out:
# Date_month_year
# 2015-01-04                                  No Internet service
# 2015-01-04       Comcast Customer Service; Theft; Inconsistency
# 2015-01-04                                    Incorrect Billing
# 2015-01-04                                        comcast cable
# 2015-01-04    Comcast speeds as low as 12 MB/s, paying for 1...
#                                     ...
# 2015-05-31                                              Comcast
# 2015-05-31                 Comcast of East Windsor NJ Complaint
# 2015-05-31                                          n/a (b) (6)
# 2015-05-31    Complaint against Comcast for incredibly bad s...
# 2015-05-31                       Questionable internet slowdown
# Name: Customer Complaint, Length: 2214, dtype: object

# %%
#Which complaint types are maximum i.e., around internet, network issues, or across any other domains.
internet_issues1=df[df['Customer Complaint'].str.contains('network')].count()

# %%
internet_issues2=df[df['Customer Complaint'].str.contains('speed')].count()

# %%
internet_issues3=df[df['Customer Complaint'].str.contains('data')].count()

# %%
internet_issues4=df[df['Customer Complaint'].str.contains('internet')].count()

# %%
billing_issues1=df[df['Customer Complaint'].str.contains('billing')].count()

# %%
billing_issues2=df[df['Customer Complaint'].str.contains('bill')].count()

# %%
billing_issues3=df[df['Customer Complaint'].str.contains('charges')].count()

# %%
service_issues1=df[df['Customer Complaint'].str.contains('service')].count()

# %%
service_issues2=df[df['Customer Complaint'].str.contains('customer')].count()

# %%
total_number_internet_issues=internet_issues1+internet_issues2+internet_issues3+internet_issues4

# %%
total_number_internet_issues
# Out:
# Customer Complaint             374
# Date                           374
# Received Via                   374
# City                           374
# State                          374
# Zip code                       374
# Status                         374
# Filing on Behalf of Someone    374
# dtype: int64

# %%
total_number_billing_issues=billing_issues1+billing_issues2+billing_issues3

# %%
total_number_billing_issues
# Out:
# Customer Complaint             353
# Date                           353
# Received Via                   353
# City                           353
# State                          353
# Zip code                       353
# Status                         353
# Filing on Behalf of Someone    353
# dtype: int64

# %%
total_number_service_issues=service_issues1+service_issues2

# %%
total_number_service_issues
# Out:
# Customer Complaint             360
# Date                           360
# Received Via                   360
# City                           360
# State                          360
# Zip code                       360
# Status                         360
# Filing on Behalf of Someone    360
# dtype: int64

# %%
total_number_issues=total_number_internet_issues+total_number_billing_issues+total_number_service_issues

# %%
total_number_issues
# Out:
# Customer Complaint             1087
# Date                           1087
# Received Via                   1087
# City                           1087
# State                          1087
# Zip code                       1087
# Status                         1087
# Filing on Behalf of Someone    1087
# dtype: int64

# %%
df.shape
# Out:
# (2224, 8)

# %%
other_issue=2224-total_number_issues

# %%
other_issue
# Out:
# Customer Complaint             1137
# Date                           1137
# Received Via                   1137
# City                           1137
# State                          1137
# Zip code                       1137
# Status                         1137
# Filing on Behalf of Someone    1137
# dtype: int64

# %%
df['Status'].unique()
# Out:
# array(['Closed', 'Open', 'Solved', 'Pending'], dtype=object)

# %%
#Create a new categorical variable with value as Open and Closed. Open & Pending is to be categorized as Open and Closed & Solved is to be categorized as Closed
df['newstatus']=['Open' if status=='Open' or status == 'Pending' else 'Closed' for status in df['Status']]

# %%
df.sample(10)
# Out:
#                                                 Customer Complaint      Date  \
# Date_month_year
# 2015-05-15                            Comcast services not working  15-05-15
# 2015-06-23       online adertised price was not honored over phone  23-06-15
# 2015-05-18       Comcast Blocking HBO Go on Sony PlayStation de...  18-05-15
# 2015-06-28       Comcast business keeps moving my same-day trou...  28-06-15
# 2015-08-05       Comcast/Xfinity: Poor internet connection spee...  05-08-15
# 2015-04-14                          Comcast won't pay me my refund  14-04-15
# 2015-07-04                  Customer Service and Billing Complaint  04-07-15
# 2015-02-06                                                 Comcast  06-02-15
# 2015-08-05       Ongoing serious and cotinued internet service ...  05-08-15
# 2015-06-27                     Comcast monopoly bundling practices  27-06-15
#
#                        Received Via             City          State  Zip code  \
# Date_month_year
# ...

# %%
state_complain=df.groupby(['State','newstatus']).size().unstack()

# %%
state_complain
# Out:
# newstatus             Closed  Open
# State
# Alabama                 17.0   9.0
# Arizona                 14.0   6.0
# Arkansas                 6.0   NaN
# California             159.0  61.0
# Colorado                58.0  22.0
# Connecticut              9.0   3.0
# Delaware                 8.0   4.0
# District Of Columbia    14.0   2.0
# District of Columbia     1.0   NaN
# Florida                201.0  39.0
# Georgia                208.0  80.0
# Illinois               135.0  29.0
# Indiana                 50.0   9.0
# Iowa                     1.0   NaN
# Kansas                   1.0   1.0
# Kentucky                 4.0   3.0
# Louisiana               12.0   1.0
# Maine                    3.0   2.0
# Maryland                63.0  15.0
# Massachusetts           50.0  11.0
# Michigan                92.0  23.0
# Minnesota               29.0   4.0
# Mississippi             23.0  16.0
# Missouri                 3.0   1.0
# Montana                  1.0   NaN
# ...

# %%
#Provide state wise status of complaints in a stacked bar chart. Use the categorized variable from Q3
state_complain.plot.bar(figsize=(10,10),stacked=True)
# Out:
# <AxesSubplot:xlabel='State'>

# %%
#Which state has the maximum complaints
df.groupby(['State']).size().sort_values(ascending=False)[:5]
# Out:
# State
# Georgia       288
# Florida       240
# California    220
# Illinois      164
# Tennessee     143
# dtype: int64

# %%
df['newstatus'].value_counts()
# Out:
# Closed    1707
# Open       517
# Name: newstatus, dtype: int64

# %%
unresolved_data=df.groupby(['State','newstatus']).size().unstack().fillna(0).sort_values(by='Open',ascending=False)

# %%
unresolved_data
# Out:
# newstatus             Closed  Open
# State
# Georgia                208.0  80.0
# California             159.0  61.0
# Tennessee               96.0  47.0
# Florida                201.0  39.0
# Illinois               135.0  29.0
# Washington              75.0  23.0
# Michigan                92.0  23.0
# Colorado                58.0  22.0
# Texas                   49.0  22.0
# Pennsylvania           110.0  20.0
# New Jersey              56.0  19.0
# Mississippi             23.0  16.0
# Maryland                63.0  15.0
# Oregon                  36.0  13.0
# Virginia                49.0  11.0
# Massachusetts           50.0  11.0
# Alabama                 17.0   9.0
# Indiana                 50.0   9.0
# Utah                    16.0   6.0
# Arizona                 14.0   6.0
# New Hampshire            8.0   4.0
# New Mexico              11.0   4.0
# Minnesota               29.0   4.0
# Delaware                 8.0   4.0
# West Virginia            8.0   3.0
# ...

# %%
unresolved_data['unresloved_cmp_prec']=unresolved_data['Open']/unresolved_data['Open'].sum()*100

# %%
#Which state has the highest percentage of unresolved complaints
unresolved_data
# Out:
# newstatus             Closed  Open  unresloved_cmp_prec
# State
# Georgia                208.0  80.0            15.473888
# California             159.0  61.0            11.798839
# Tennessee               96.0  47.0             9.090909
# Florida                201.0  39.0             7.543520
# Illinois               135.0  29.0             5.609284
# Washington              75.0  23.0             4.448743
# Michigan                92.0  23.0             4.448743
# Colorado                58.0  22.0             4.255319
# Texas                   49.0  22.0             4.255319
# Pennsylvania           110.0  20.0             3.868472
# New Jersey              56.0  19.0             3.675048
# Mississippi             23.0  16.0             3.094778
# Maryland                63.0  15.0             2.901354
# Oregon                  36.0  13.0             2.514507
# Virginia                49.0  11.0             2.127660
# Massachusetts           50.0  11.0             2.127660
# ...

# %%
unresolved_data.plot()
# Out:
# <AxesSubplot:xlabel='State'>

# %%
resolved_data=df.groupby(['Received Via','newstatus']).size().unstack().fillna(0)

# %%
resolved_data['resolved']=resolved_data['Closed']/resolved_data['Closed'].sum()*100

# %%
#Provide the percentage of complaints resolved till date, which were received through the Internet and customer care calls
resolved_data['resolved']
# Out:
# Received Via
# Customer Care Call    50.615114
# Internet              49.384886
# Name: resolved, dtype: float64

# %%
resolved_data.plot.bar(figsize=(10,7))
# Out:
# <AxesSubplot:xlabel='Received Via'>
